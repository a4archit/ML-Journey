# %% [markdown]
# # **Random Forest:** *Basic Implementation*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, root_mean_squared_error, balanced_accuracy_score
from mlxtend.plotting import plot_decision_regions

# %%
try:
    df = pd.read_csv(r"/workspaces/ML-Journey/Datasets/Dataset for weight prediction with gender.csv")
except:
    df = pd.read_csv(r"C:\\Users\\Archit\\Documents\\GitHub\\ML-Journey\\Datasets\\Dataset for weight prediction with gender.csv")

# %%
X = df.drop(columns=['weight_kg'])
y = df[['weight_kg']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
scaler = StandardScaler()
X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %% [markdown]
# ### Model with undscalised data

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# c:\Users\Archit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.8708962078941651

# %% [markdown]
# ### Model with scalised data

# %%
rf1 = RandomForestRegressor()
rf1.fit(X_train_trf, y_train)
y_pred = rf1.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# c:\Users\Archit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.8710248342754277

# %% [markdown]
# ### Manual hyperparameter tunning

# %%
rf2 = RandomForestRegressor(n_estimators=50, max_features=2, oob_score=True , ccp_alpha=0.09)
rf2.fit(X_train_trf, y_train)
y_pred = rf2.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# c:\Users\Archit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.8780955336777201

# %% [markdown]
# ### Hyperparameter Tunning with grid search cv

# %%
param_grid = {
    "n_estimators": [10,30,50],
    "max_depth": [2,5,7],
    "ccp_alpha": [00000.1, 0.1, 1]
}

grid = GridSearchCV(estimator=RandomForestRegressor(),
                    cv = 5,
                    param_grid = param_grid,
                    scoring = 'neg_mean_squared_error')

# %%
grid.fit(X_train_trf, y_train.to_numpy().ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'ccp_alpha': [0.1, 0.1, 1], 'max_depth': [2, 5, 7],
#                          'n_estimators': [10, 30, 50]},
#              scoring='neg_mean_squared_error')

# %%
best = grid.best_estimator_

# %%
y_pred = best.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# 0.8762260136862893

# %% [markdown]
# ### Exploring random forest

# %%
rf.estimators_
# Out:
# [DecisionTreeRegressor(max_features=1.0, random_state=1672049516),
#  DecisionTreeRegressor(max_features=1.0, random_state=228990243),
#  DecisionTreeRegressor(max_features=1.0, random_state=1261089399),
#  DecisionTreeRegressor(max_features=1.0, random_state=1276383056),
#  DecisionTreeRegressor(max_features=1.0, random_state=384384193),
#  DecisionTreeRegressor(max_features=1.0, random_state=902648654),
#  DecisionTreeRegressor(max_features=1.0, random_state=134044915),
#  DecisionTreeRegressor(max_features=1.0, random_state=596806913),
#  DecisionTreeRegressor(max_features=1.0, random_state=152455659),
#  DecisionTreeRegressor(max_features=1.0, random_state=602755181),
#  DecisionTreeRegressor(max_features=1.0, random_state=1414497188),
#  DecisionTreeRegressor(max_features=1.0, random_state=550792755),
#  DecisionTreeRegressor(max_features=1.0, random_state=1242447622),
#  DecisionTreeRegressor(max_features=1.0, random_state=2052148686),
#  DecisionTreeRegressor(max_features=1.0, random_state=1242749777),
#  DecisionTreeRegressor(max_features=1.0, random_state=1112969920),
#  DecisionTreeRegressor(max_features=1.0, random_state=144395494),
#  DecisionTreeRegressor(max_features=1.0, random_state=404404134),
#  DecisionTreeRegressor(max_features=1.0, random_state=632020302),
#  DecisionTreeRegressor(max_features=1.0, random_state=355749144),
#  DecisionTreeRegressor(max_features=1.0, random_state=214301667),
#  DecisionTreeRegressor(max_features=1.0, random_state=1836551185),
#  DecisionTreeRegressor(max_features=1.0, random_state=2083103069),
#  DecisionTreeRegressor(max_features=1.0, random_state=1428059176),
#  DecisionTreeRegressor(max_features=1.0, random_state=2012387863),
#  DecisionTreeRegressor(max_features=1.0, random_state=2082134276),
#  DecisionTreeRegressor(max_features=1.0, random_state=185428941),
#  DecisionTreeRegressor(max_features=1.0, random_state=1850318427),
#  DecisionTreeRegressor(max_features=1.0, random_state=1122843718),
#  DecisionTreeRegressor(max_features=1.0, random_state=2037193762),
#  DecisionTreeRegressor(max_features=1.0, random_state=1538689960),
#  DecisionTreeRegressor(max_features=1.0, random_state=1211630336),
#  DecisionTreeRegressor(max_features=1.0, random_state=426631190),
#  DecisionTreeRegressor(max_features=1.0, random_state=2073075894),
#  DecisionTreeRegressor(max_features=1.0, random_state=883161127),
#  DecisionTreeRegressor(max_features=1.0, random_state=104984112),
#  DecisionTreeRegressor(max_features=1.0, random_state=1508421576),
#  DecisionTreeRegressor(max_features=1.0, random_state=1766279791),
#  DecisionTreeRegressor(max_features=1.0, random_state=1660639538),
#  DecisionTreeRegressor(max_features=1.0, random_state=1700855421),
#  DecisionTreeRegressor(max_features=1.0, random_state=543073293),
#  DecisionTreeRegressor(max_features=1.0, random_state=1656134370),
#  DecisionTreeRegressor(max_features=1.0, random_state=759570482),
#  DecisionTreeRegressor(max_features=1.0, random_state=958662063),
#  DecisionTreeRegressor(max_features=1.0, random_state=782902975),
#  DecisionTreeRegressor(max_features=1.0, random_state=2080980836),
#  DecisionTreeRegressor(max_features=1.0, random_state=1534978714),
#  DecisionTreeRegressor(max_features=1.0, random_state=1993489833),
#  DecisionTreeRegressor(max_features=1.0, random_state=19223775),
#  DecisionTreeRegressor(max_features=1.0, random_state=751799960),
#  DecisionTreeRegressor(max_features=1.0, random_state=793627676),
#  DecisionTreeRegressor(max_features=1.0, random_state=1994816562),
#  DecisionTreeRegressor(max_features=1.0, random_state=1499858126),
#  DecisionTreeRegressor(max_features=1.0, random_state=1731217932),
#  DecisionTreeRegressor(max_features=1.0, random_state=1182292815),
#  DecisionTreeRegressor(max_features=1.0, random_state=2128750077),
#  DecisionTreeRegressor(max_features=1.0, random_state=795687161),
#  DecisionTreeRegressor(max_features=1.0, random_state=146445357),
#  DecisionTreeRegressor(max_features=1.0, random_state=411690632),
#  DecisionTreeRegressor(max_features=1.0, random_state=1885186112),
#  DecisionTreeRegressor(max_features=1.0, random_state=846521397),
#  DecisionTreeRegressor(max_features=1.0, random_state=829140763),
#  DecisionTreeRegressor(max_features=1.0, random_state=1736650507),
#  DecisionTreeRegressor(max_features=1.0, random_state=605321439),
#  DecisionTreeRegressor(max_features=1.0, random_state=1259963285),
#  DecisionTreeRegressor(max_features=1.0, random_state=2141199678),
#  DecisionTreeRegressor(max_features=1.0, random_state=2031798936),
#  DecisionTreeRegressor(max_features=1.0, random_state=1875274639),
#  DecisionTreeRegressor(max_features=1.0, random_state=282890941),
#  DecisionTreeRegressor(max_features=1.0, random_state=501794620),
#  DecisionTreeRegressor(max_features=1.0, random_state=1800960038),
#  DecisionTreeRegressor(max_features=1.0, random_state=287943960),
#  DecisionTreeRegressor(max_features=1.0, random_state=106971814),
#  DecisionTreeRegressor(max_features=1.0, random_state=367087208),
#  DecisionTreeRegressor(max_features=1.0, random_state=1738236770),
#  DecisionTreeRegressor(max_features=1.0, random_state=307677018),
#  DecisionTreeRegressor(max_features=1.0, random_state=1007348393),
#  DecisionTreeRegressor(max_features=1.0, random_state=1988851267),
#  DecisionTreeRegressor(max_features=1.0, random_state=2011082097),
#  DecisionTreeRegressor(max_features=1.0, random_state=1859607666),
#  DecisionTreeRegressor(max_features=1.0, random_state=2014446285),
#  DecisionTreeRegressor(max_features=1.0, random_state=1336451258),
#  DecisionTreeRegressor(max_features=1.0, random_state=1302650554),
#  DecisionTreeRegressor(max_features=1.0, random_state=751114628),
#  DecisionTreeRegressor(max_features=1.0, random_state=1534043819),
#  DecisionTreeRegressor(max_features=1.0, random_state=414521342),
#  DecisionTreeRegressor(max_features=1.0, random_state=294780807),
#  DecisionTreeRegressor(max_features=1.0, random_state=1052127212),
#  DecisionTreeRegressor(max_features=1.0, random_state=2068081486),
#  DecisionTreeRegressor(max_features=1.0, random_state=1349525903),
#  DecisionTreeRegressor(max_features=1.0, random_state=2012918557),
#  DecisionTreeRegressor(max_features=1.0, random_state=1021551526),
#  DecisionTreeRegressor(max_features=1.0, random_state=1933846239),
#  DecisionTreeRegressor(max_features=1.0, random_state=1699429558),
#  DecisionTreeRegressor(max_features=1.0, random_state=1369839473),
#  DecisionTreeRegressor(max_features=1.0, random_state=887100917),
#  DecisionTreeRegressor(max_features=1.0, random_state=1041565516),
#  DecisionTreeRegressor(max_features=1.0, random_state=230300269),
#  DecisionTreeRegressor(max_features=1.0, random_state=428522494),
#  DecisionTreeRegressor(max_features=1.0, random_state=204544345)]

# %%
rf.estimator_
# Out:
# DecisionTreeRegressor()

# %%
rf.feature_importances_
# Out:
# array([0.18711594, 0.50207602, 0.17596548, 0.06813937, 0.05162697,
#        0.01507622])

# %%
rf.feature_names_in_
# Out:
# array(['height_cm', 'gender', 'bmi_class_Normal', 'bmi_class_Obesity',
#        'bmi_class_Overweight', 'bmi_class_Underweight'], dtype=object)

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf.n_features_in_
# Out:
# 6

# %%
rf.n_outputs_
# Out:
# 1

# %%
rf._estimator_type
# Out:
# 'regressor'

# %%
rf.n_estimators
# Out:
# 100
