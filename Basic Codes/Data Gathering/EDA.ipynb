# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Archit\Downloads\bodyPerformance.csv')

# %%
df.shape
# Out:
# (13393, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13393 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13393 non-null  float64
#  1   gender                   13393 non-null  object
#  2   height_cm                13393 non-null  float64
#  3   weight_kg                13393 non-null  float64
#  4   body fat_%               13393 non-null  float64
#  5   diastolic                13393 non-null  float64
#  6   systolic                 13393 non-null  float64
#  7   gripForce                13393 non-null  float64
#  8   sit and bend forward_cm  13393 non-null  float64
#  9   sit-ups counts           13393 non-null  float64
#  10  broad jump_cm            13393 non-null  float64
#  11  class                    13393 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.2+ MB

# %%
df.sample()
# Out:
#        age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 5430  31.0      M      176.9       70.9        18.7       80.0     128.0
#
#       gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 5430       43.3                     14.9            45.0          209.0     B

# %%
df.isnull().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df.sample(2)
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 12220  22.0      F      163.4       75.0        33.2       61.0     121.0
# 5283   27.0      M      176.9       76.6        13.5       81.0     137.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 12220       31.5                     16.0            39.0          172.0     D
# 5283        53.5                     32.0            56.0          262.0     C

# %% [markdown]
# ## **Univariate Analysis**

# %%
sns.countplot(df['gender'])
# Out:
# <Axes: xlabel='count', ylabel='gender'>

# %%
df['class'].value_counts().plot(kind='pie', autopct="% .3f %%")
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['age'], bins=23)
# Out:
# (array([1753., 1285., 1273., 1073.,  781.,  613.,  458.,  223.,  521.,
#          473.,  428.,  371.,  355.,  353.,  359.,  189.,  331.,  287.,
#          382.,  361.,  560.,  519.,  445.]),
#  array([21.        , 22.86956522, 24.73913043, 26.60869565, 28.47826087,
#         30.34782609, 32.2173913 , 34.08695652, 35.95652174, 37.82608696,
#         39.69565217, 41.56521739, 43.43478261, 45.30434783, 47.17391304,
#         49.04347826, 50.91304348, 52.7826087 , 54.65217391, 56.52173913,
#         58.39130435, 60.26086957, 62.13043478, 64.        ]),
#  <BarContainer object of 23 artists>)

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\Archit\AppData\Local\Temp\ipykernel_6256\3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(df['body fat_%'])
# Out:
# <Axes: ylabel='body fat_%'>

# %% [markdown]
# ## **Bivariate and Multivariate Analysis**

# %%
df.sample(5)
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 2106   26.0      F      162.7       51.4        22.5       57.0     106.0
# 2759   23.0      M      162.2       61.5        10.9       73.0     114.0
# 4457   21.0      M      168.3       64.8        17.8       77.0     135.0
# 4703   36.0      M      169.6       65.2        15.9       86.0     140.0
# 10226  23.0      M      171.2       67.4        15.2       81.0     134.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 2106        22.7                     15.7            40.0          191.0     B
# 2759        35.9                     11.0            55.0          247.0     C
# 4457        39.2                    -10.7            40.0          212.0     D
# 4703        43.3                     21.0            59.0          216.0     A
# 10226       47.8                      7.6            42.0          239.0     C

# %%
sns.scatterplot(x=df['sit-ups counts'], y=df['broad jump_cm'], hue=df['class'], style=df['gender'], size=df['weight_kg'])
# sns.scatterplot(df['broad jump_cm'])
# Out:
# <Axes: xlabel='sit-ups counts', ylabel='broad jump_cm'>

# %%
sns.barplot(y=df['height_cm'], x=df['class'], hue=df['gender'])
# Out:
# <Axes: xlabel='class', ylabel='height_cm'>

# %%
sns.boxplot(y=df['height_cm'], x=df['class'], hue=df['gender'])
# Out:
# <Axes: xlabel='class', ylabel='height_cm'>

# %%
sns.distplot(x=df['height_cm'], hist=0)
sns.distplot(x=df['weight_kg'], hist=0)
# Out:
# C:\Users\Archit\AppData\Local\Temp\ipykernel_6256\2670516021.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['height_cm'], hist=0)
# C:\Users\Archit\AppData\Local\Temp\ipykernel_6256\2670516021.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.heatmap(pd.crosstab(df['gender'], df['class']))
# Out:
# <Axes: xlabel='class', ylabel='gender'>

# %%
sns.pairplot(df)

# %%
sns.lineplot(x=df['height_cm'], y=df['weight_kg'])
# Out:
# <Axes: xlabel='height_cm', ylabel='weight_kg'>
