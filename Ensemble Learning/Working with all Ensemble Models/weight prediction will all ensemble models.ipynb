# %% [markdown]
# # Weight Predictor using several algorithms with many **Ensemble Techniques**.

# %% [markdown]
# ## Model Structure
# ***
# `model`<br>
#     | <br>
#     |----- `v1` (*bagging*)<br>
#     |       |<br>
#     |       |<br>
#     |       |----- `knn`<br>
#     |       |<br>
#     |       |----- `lr`<br>
#     |       |<br>
#     |       |----- `dtree`<br>
#     |       |<br>
#     |       |----- `elasticnet`<br>
#     |<br>
#     |<br>
#     |----- `v2` (*boosting: adaboost*)<br>
#     |       |<br>
#     |       |<br>
#     |       |----- `knn`<br>
#     |       |<br>
#     |       |----- `lr`<br>
#     |       |<br>
#     |       |----- `dtree`<br>
#     |       |<br>
#     |       |----- `elasticnet`<br>
#     |<br>
#     |<br>
#     |----- `v3` (*bagging & boosting*)<br>
#     |       |<br>
#     |       |<br>
#     |       |----- `rf` (*bagging*)<br>
#     |       |<br>
#     |       |----- `rf` (*boosting*)<br>

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import AdaBoostRegressor, VotingRegressor, BaggingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import Normalizer
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, root_mean_squared_error, balanced_accuracy_score
from mlxtend.plotting import plot_decision_regions

# %%
try:
    df = pd.read_csv(r"/workspaces/ML-Journey/Datasets/Dataset for weight prediction with gender.csv")
except:
    df = pd.read_csv(r"C:\\Users\\Archit\\Documents\\GitHub\\ML-Journey\\Datasets\\Dataset for weight prediction with gender.csv")

X = df.drop(columns=['weight_kg'])
y = df[['weight_kg']]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

norm = Normalizer()
X_train_trf = norm.fit_transform(X_train)
X_test_trf = norm.transform(X_test)

# %% [markdown]
# <br><br><br>
# ## `v1` - Bagging (L0)
# ***

# %% [markdown]
# ### KNN -> Bagging

# %%
knn_bag = BaggingRegressor(KNeighborsRegressor(n_neighbors=15))
knn_bag.fit(X_train_trf, y_train)
y_pred = knn_bag.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/ensemble/_bagging.py:581: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# 0.8767212282796998

# %% [markdown]
# ### Linear Regression -> Bagging

# %%
lr_bag = BaggingRegressor(LinearRegression())
lr_bag.fit(X_train_trf, y_train)
y_pred = lr_bag.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/ensemble/_bagging.py:581: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# 0.8739140652027122

# %% [markdown]
# ### Elasticnet -> Bagging

# %%
elasticnet_bag = BaggingRegressor(ElasticNet(alpha=0.001), n_estimators=50)
elasticnet_bag.fit(X_train, y_train)
y_pred = elasticnet_bag.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/ensemble/_bagging.py:581: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# 0.876129443809892

# %% [markdown]
# ### Decision Tree -> Bagging

# %%
dtree_bag = BaggingRegressor(DecisionTreeRegressor(ccp_alpha=0.1), n_estimators=50)
dtree_bag.fit(X_train_trf, y_train)
y_pred = dtree_bag.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/ensemble/_bagging.py:581: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# 0.8768464793563044

# %% [markdown]
# <br><br><br>
# ## `v2` - Boosting (L0)
# ***

# %% [markdown]
# ### KNN - Boosting

# %%
knn_bos = AdaBoostRegressor(KNeighborsRegressor(n_neighbors=7), random_state=420)
knn_bos.fit(X_train_trf, y_train)
y_pred = knn_bos.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8698867962090915

# %% [markdown]
# ### Linear Regression - Boosting

# %%
lr_bos = AdaBoostRegressor(LinearRegression(), learning_rate=0.01)
lr_bos.fit(X_train_trf, y_train)
y_pred = lr_bos.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8739812848463383

# %% [markdown]
# ### ElasticNet -> Boosting

# %%
elasticnet_bos = AdaBoostRegressor(ElasticNet(alpha=0.25, tol=7),learning_rate=0.1, random_state=4200, n_estimators=500)
elasticnet_bos.fit(X_train, y_train)
y_pred = elasticnet_bos.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8618523709932356

# %% [markdown]
# ### Decision Tree -> Boosting

# %%
dtree_bos = AdaBoostRegressor(DecisionTreeRegressor(ccp_alpha=0.1), n_estimators=50, learning_rate=0.001)
dtree_bos.fit(X_train_trf, y_train)
y_pred = dtree_bos.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8747958805048787

# %% [markdown]
# <br><br><br>
# ## `v3` - Bagging & Boosting (L0)
# ***

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestRegressor(ccp_alpha=0.1)
rf.fit(X_train_trf, y_train)
y_pred = rf.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.8770416943320881

# %% [markdown]
# ### Random Forest -> Bagging

# %%
rf_bag = BaggingRegressor(RandomForestRegressor(ccp_alpha=0.1), n_estimators=5)
rf_bag.fit(X_train_trf, y_train)
y_pred = rf_bag.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/ensemble/_bagging.py:581: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# 0.877157020277395

# %% [markdown]
# ### Random Forest -> Boosting

# %%
rf_bos = AdaBoostRegressor(RandomForestRegressor(ccp_alpha=0.1), n_estimators=5, random_state=42)
rf_bos.fit(X_train_trf, y_train)
y_pred = rf_bos.predict(X_test_trf)
r2_score(y_test, y_pred)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8760689146450875

# %% [markdown]
# <br><br><br>
# ## L1
# ***

# %%
v1 = VotingRegressor( estimators=[
    ('knn', knn_bag),
    ('lr', lr_bag),
    ('dt', dtree_bag),
    ('en', elasticnet_bag)
])
v1
# Out:
# VotingRegressor(estimators=[('knn',
#                              BaggingRegressor(estimator=KNeighborsRegressor(n_neighbors=15))),
#                             ('lr',
#                              BaggingRegressor(estimator=LinearRegression())),
#                             ('dt',
#                              BaggingRegressor(estimator=DecisionTreeRegressor(ccp_alpha=0.1),
#                                               n_estimators=50)),
#                             ('en',
#                              BaggingRegressor(estimator=ElasticNet(alpha=0.001),
#                                               n_estimators=50))])

# %%
v2 = VotingRegressor( estimators=[
    ('knn', knn_bos),
    ('lr', lr_bos),
    ('dt', dtree_bos),
    ('en', elasticnet_bos)
])
v2
# Out:
# VotingRegressor(estimators=[('knn',
#                              AdaBoostRegressor(estimator=KNeighborsRegressor(n_neighbors=7),
#                                                random_state=420)),
#                             ('lr',
#                              AdaBoostRegressor(estimator=LinearRegression(),
#                                                learning_rate=0.01)),
#                             ('dt',
#                              AdaBoostRegressor(estimator=DecisionTreeRegressor(ccp_alpha=0.1),
#                                                learning_rate=0.001)),
#                             ('en',
#                              AdaBoostRegressor(estimator=ElasticNet(alpha=0.25,
#                                                                     tol=7),
#                                                learning_rate=0.1,
#                                                n_estimators=500,
#                                                random_state=4200))])

# %%
v3 = VotingRegressor(estimators=[
    ('rf', rf),
    ('rf_bag', rf_bag),
    ('rf_bos', rf_bos)
])
v3
# Out:
# VotingRegressor(estimators=[('rf', RandomForestRegressor(ccp_alpha=0.1)),
#                             ('rf_bag',
#                              BaggingRegressor(estimator=RandomForestRegressor(ccp_alpha=0.1),
#                                               n_estimators=5)),
#                             ('rf_bos',
#                              AdaBoostRegressor(estimator=RandomForestRegressor(ccp_alpha=0.1),
#                                                n_estimators=5,
#                                                random_state=42))])

# %% [markdown]
# <br><br>
#
# ## L2
# ***

# %%
model = VotingRegressor(estimators=[
    ('v1',v1),
    ('v2',v2),
    ('v3',v3)
])

# %%
model.fit(X_train_trf, y_train)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/ensemble/_voting.py:694: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# VotingRegressor(estimators=[('v1',
#                              VotingRegressor(estimators=[('knn',
#                                                           BaggingRegressor(estimator=KNeighborsRegressor(n_neighbors=15))),
#                                                          ('lr',
#                                                           BaggingRegressor(estimator=LinearRegression())),
#                                                          ('dt',
#                                                           BaggingRegressor(estimator=DecisionTreeRegressor(ccp_alpha=0.1),
#                                                                            n_estimators=50)),
#                                                          ('en',
#                                                           BaggingRegressor(estimator=ElasticNet(alpha=0.001),
#                                                                            n_estimators=50))...
#                                                           AdaBoostRegressor(estimator=ElasticNet(alpha=0.25,
#                                                                                                  tol=7),
#                                                                             learning_rate=0.1,
#                                                                             n_estimators=500,
#                                                                             random_state=4200))])),
#                             ('v3',
#                              VotingRegressor(estimators=[('rf',
#                                                           RandomForestRegressor(ccp_alpha=0.1)),
#                                                          ('rf_bag',
#                                                           BaggingRegressor(estimator=RandomForestRegressor(ccp_alpha=0.1),
#                                                                            n_estimators=5)),
#                                                          ('rf_bos',
#                                                           AdaBoostRegressor(estimator=RandomForestRegressor(ccp_alpha=0.1),
#                                                                             n_estimators=5,
#                                                                             random_state=42))]))])

# %%
model_pred = model.predict(X_test_trf)

# %%
r2_score(y_test, model_pred)
# Out:
# 0.8544922510158113
